# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('.')

import math
import matplotlib.pyplot as plt
from yop import parser
from pathlib import Path

# %%
x = [1, 2, 3]
y = [4, 6, 8]
plt.plot(x, y)
